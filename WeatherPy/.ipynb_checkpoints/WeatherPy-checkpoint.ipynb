# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url =  'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid='+ weather_api_key

city_record=[]
city_cloud=[]
city_country=[]
city_date=[]
city_humidity=[]
city_lat=[]
city_lng=[]
city_maxtemp=[]
city_wind=[]

print("Beginning Data Retrieval")
print("-----------------------------")


record_counter=1
set_counter=1

for i, city in enumerate(cities):
    
    if(i % 50 == 0 and i>=50):
        set_counter+=1
        record_counter=1
        
        
    query_url = url + "&q=" + city
    
    print(f'Processing Record '+ str(record_counter) +' of Set '+ str(set_counter) +' | ' +str(city))
    
    record_counter += 1
    
    try:
        city_weather= requests.get(query_url).json()
        
        city_record.append(city_weather['name'])
        city_cloud.append(city_weather['clouds']['all'])
        city_country.append(city_weather['sys']['country'])
        city_date.append(city_weather['dt'])
        city_humidity.append(city_weather['main']['humidity'])
        city_lat.append(city_weather['coord']['lat'])
        city_lng.append(city_weather['coord']['lon'])
        city_maxtemp.append(city_weather['main']['temp_max'])
        city_wind.append(city_weather['wind']['speed'])
    
    except:
        print(f''+city + ' was not found in openweathermap API')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | prince rupert
# Processing Record 5 of Set 1 | bubaque
# Processing Record 6 of Set 1 | san jose
# Processing Record 7 of Set 1 | berbera
# berberawas not found in openweathermap API
# Processing Record 8 of Set 1 | husavik
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | tsihombe
# tsihombewas not found in openweathermap API
# Processing Record 12 of Set 1 | eyemouth
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | rochegda
# Processing Record 15 of Set 1 | zhigansk
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | te anau
# Processing Record 18 of Set 1 | adrar
# Processing Record 19 of Set 1 | verkhnyaya toyma
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | skjervoy
# Processing Record 22 of Set 1 | kushmurun
# kushmurunwas not found in openweathermap API
# Processing Record 23 of Set 1 | cairns
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | nemuro
# Processing Record 27 of Set 1 | sao filipe
# Processing Record 28 of Set 1 | dodge city
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | san patricio
# Processing Record 32 of Set 1 | taltal
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | lazaro cardenas
# Processing Record 35 of Set 1 | namibe
# Processing Record 36 of Set 1 | taolanaro
# taolanarowas not found in openweathermap API
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | lolua
# loluawas not found in openweathermap API
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | souillac
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | cockburn town
# Processing Record 44 of Set 1 | labuhan
# Processing Record 45 of Set 1 | lloydminster
# Processing Record 46 of Set 1 | udachnyy
# Processing Record 47 of Set 1 | mucurapo
# Processing Record 48 of Set 1 | butembo
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | touros
# Processing Record 4 of Set 2 | umm durman
# umm durmanwas not found in openweathermap API
# Processing Record 5 of Set 2 | chiang rai
# Processing Record 6 of Set 2 | mangrol
# Processing Record 7 of Set 2 | amderma
# amdermawas not found in openweathermap API
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | belushya guba
# belushya gubawas not found in openweathermap API
# Processing Record 12 of Set 2 | anloga
# Processing Record 13 of Set 2 | pitimbu
# Processing Record 14 of Set 2 | airai
# Processing Record 15 of Set 2 | menongue
# Processing Record 16 of Set 2 | karaul
# karaulwas not found in openweathermap API
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | san juan
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | bafia
# Processing Record 22 of Set 2 | university park
# Processing Record 23 of Set 2 | sonqor
# Processing Record 24 of Set 2 | honiara
# Processing Record 25 of Set 2 | agadir
# Processing Record 26 of Set 2 | makaryev
# Processing Record 27 of Set 2 | dasoguz
# Processing Record 28 of Set 2 | fortuna
# Processing Record 29 of Set 2 | moose factory
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | bengkulu
# bengkuluwas not found in openweathermap API
# Processing Record 32 of Set 2 | cidreira
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | sorong
# Processing Record 35 of Set 2 | baruun-urt
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | wairoa
# Processing Record 38 of Set 2 | korla
# korlawas not found in openweathermap API
# Processing Record 39 of Set 2 | zachagansk
# zachaganskwas not found in openweathermap API
# Processing Record 40 of Set 2 | ighiu
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | bandarbeyla
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | sentyabrskiy
# sentyabrskiywas not found in openweathermap API
# Processing Record 46 of Set 2 | uyemskiy
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | puerto del rosario
# Processing Record 49 of Set 2 | la ronge
# Processing Record 50 of Set 2 | quatre cocos
# Processing Record 1 of Set 3 | zhuhai
# Processing Record 2 of Set 3 | gejiu
# Processing Record 3 of Set 3 | waingapu
# Processing Record 4 of Set 3 | utiel
# Processing Record 5 of Set 3 | yumen
# Processing Record 6 of Set 3 | nikolayevka
# Processing Record 7 of Set 3 | cape town
# Processing Record 8 of Set 3 | mys shmidta
# mys shmidtawas not found in openweathermap API
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | vila do maio
# Processing Record 12 of Set 3 | leningradskiy
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | fort-shevchenko
# Processing Record 16 of Set 3 | muyezerskiy
# Processing Record 17 of Set 3 | sao raimundo das mangabeiras
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | batagay-alyta
# Processing Record 20 of Set 3 | leninsk
# Processing Record 21 of Set 3 | asola
# Processing Record 22 of Set 3 | dukat
# Processing Record 23 of Set 3 | sept-iles
# Processing Record 24 of Set 3 | kysyl-syr
# Processing Record 25 of Set 3 | tabou
# Processing Record 26 of Set 3 | tateyama
# Processing Record 27 of Set 3 | qianan
# Processing Record 28 of Set 3 | gazojak
# Processing Record 29 of Set 3 | portland
# Processing Record 30 of Set 3 | darhan
# Processing Record 31 of Set 3 | idenao
# Processing Record 32 of Set 3 | katherine
# Processing Record 33 of Set 3 | baghdad
# Processing Record 34 of Set 3 | kahului
# Processing Record 35 of Set 3 | ngukurr
# ngukurrwas not found in openweathermap API
# Processing Record 36 of Set 3 | verkhnyaya inta
# Processing Record 37 of Set 3 | sassandra
# Processing Record 38 of Set 3 | martinsburg
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | marcona
# marconawas not found in openweathermap API
# Processing Record 41 of Set 3 | ribeira grande
# Processing Record 42 of Set 3 | tamandare
# Processing Record 43 of Set 3 | hobyo
# Processing Record 44 of Set 3 | juegang
# Processing Record 45 of Set 3 | acapulco
# Processing Record 46 of Set 3 | georgetown
# Processing Record 47 of Set 3 | talnakh
# Processing Record 48 of Set 3 | lamar
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | eureka
# Processing Record 1 of Set 4 | dubti
# Processing Record 2 of Set 4 | necochea
# Processing Record 3 of Set 4 | alexandria
# Processing Record 4 of Set 4 | west monroe
# Processing Record 5 of Set 4 | lavrentiya
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | aykhal
# Processing Record 8 of Set 4 | deputatskiy
# Processing Record 9 of Set 4 | laguna
# Processing Record 10 of Set 4 | nyurba
# Processing Record 11 of Set 4 | ancud
# Processing Record 12 of Set 4 | mahebourg
# Processing Record 13 of Set 4 | marau
# Processing Record 14 of Set 4 | avarua
# Processing Record 15 of Set 4 | galgani
# galganiwas not found in openweathermap API
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | mocuba
# Processing Record 20 of Set 4 | la sarre
# Processing Record 21 of Set 4 | chiang kham
# Processing Record 22 of Set 4 | broken hill
# Processing Record 23 of Set 4 | saint-augustin
# Processing Record 24 of Set 4 | fria
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | tumen
# Processing Record 27 of Set 4 | port hedland
# Processing Record 28 of Set 4 | bombay
# Processing Record 29 of Set 4 | baykit
# Processing Record 30 of Set 4 | barentsburg
# barentsburgwas not found in openweathermap API
# Processing Record 31 of Set 4 | saint-louis
# Processing Record 32 of Set 4 | norman wells
# Processing Record 33 of Set 4 | kaitangata
# Processing Record 34 of Set 4 | kieta
# Processing Record 35 of Set 4 | kalakamati
# Processing Record 36 of Set 4 | cedar city
# Processing Record 37 of Set 4 | hofn
# Processing Record 38 of Set 4 | los llanos de aridane
# Processing Record 39 of Set 4 | saint-pierre
# Processing Record 40 of Set 4 | kupino
# Processing Record 41 of Set 4 | sur
# Processing Record 42 of Set 4 | sobolevo
# Processing Record 43 of Set 4 | marawi
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | yanchukan
# yanchukanwas not found in openweathermap API
# Processing Record 46 of Set 4 | constitucion
# Processing Record 47 of Set 4 | aurora
# Processing Record 48 of Set 4 | bhanvad
# Processing Record 49 of Set 4 | kalmunai
# Processing Record 50 of Set 4 | seddon
# Processing Record 1 of Set 5 | kaspiysk
# Processing Record 2 of Set 5 | attawapiskat
# attawapiskatwas not found in openweathermap API
# Processing Record 3 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 5 | shingu
# Processing Record 5 of Set 5 | hamilton
# Processing Record 6 of Set 5 | makakilo city
# Processing Record 7 of Set 5 | comodoro rivadavia
# Processing Record 8 of Set 5 | grand river south east
# grand river south eastwas not found in openweathermap API
# Processing Record 9 of Set 5 | didao
# Processing Record 10 of Set 5 | russell
# Processing Record 11 of Set 5 | tual
# Processing Record 12 of Set 5 | hendek
# Processing Record 13 of Set 5 | otane
# Processing Record 14 of Set 5 | gualaquiza
# Processing Record 15 of Set 5 | tasiilaq
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | cap malheureux
# Processing Record 18 of Set 5 | nanortalik
# Processing Record 19 of Set 5 | yartsevo
# Processing Record 20 of Set 5 | longyearbyen
# Processing Record 21 of Set 5 | birjand
# Processing Record 22 of Set 5 | umzimvubu
# umzimvubuwas not found in openweathermap API
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | luba
# Processing Record 25 of Set 5 | marrakesh
# Processing Record 26 of Set 5 | yanam
# Processing Record 27 of Set 5 | marsh harbour
# Processing Record 28 of Set 5 | saint george
# Processing Record 29 of Set 5 | kandrian
# Processing Record 30 of Set 5 | krasnyy yar
# Processing Record 31 of Set 5 | alotau
# alotauwas not found in openweathermap API
# Processing Record 32 of Set 5 | imeni poliny osipenko
# Processing Record 33 of Set 5 | sitka
# Processing Record 34 of Set 5 | noumea
# Processing Record 35 of Set 5 | north platte
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | port blair
# Processing Record 38 of Set 5 | aklavik
# Processing Record 39 of Set 5 | elk city
# Processing Record 40 of Set 5 | phan rang
# phan rangwas not found in openweathermap API
# Processing Record 41 of Set 5 | rungata
# rungatawas not found in openweathermap API
# Processing Record 42 of Set 5 | puerto cortes
# puerto corteswas not found in openweathermap API
# Processing Record 43 of Set 5 | iqaluit
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | rondonopolis
# Processing Record 46 of Set 5 | wanning
# Processing Record 47 of Set 5 | rancho palos verdes
# Processing Record 48 of Set 5 | asasa
# Processing Record 49 of Set 5 | narsaq
# Processing Record 50 of Set 5 | badarganj
# Processing Record 1 of Set 6 | bonthe
# Processing Record 2 of Set 6 | rocha
# Processing Record 3 of Set 6 | vaitupu
# vaitupuwas not found in openweathermap API
# Processing Record 4 of Set 6 | stornoway
# stornowaywas not found in openweathermap API
# Processing Record 5 of Set 6 | viedma
# Processing Record 6 of Set 6 | sidi ali
# Processing Record 7 of Set 6 | araouane
# Processing Record 8 of Set 6 | ardakan
# Processing Record 9 of Set 6 | lincoln
# Processing Record 10 of Set 6 | dunedin
# Processing Record 11 of Set 6 | camacha
# Processing Record 12 of Set 6 | kropotkin
# Processing Record 13 of Set 6 | byron bay
# Processing Record 14 of Set 6 | malanje
# Processing Record 15 of Set 6 | tapes
# Processing Record 16 of Set 6 | urumqi
# urumqiwas not found in openweathermap API
# Processing Record 17 of Set 6 | launceston
# Processing Record 18 of Set 6 | emilio carranza
# Processing Record 19 of Set 6 | umm lajj
# Processing Record 20 of Set 6 | murud
# murudwas not found in openweathermap API
# Processing Record 21 of Set 6 | tecoanapa
# Processing Record 22 of Set 6 | san fernando
# Processing Record 23 of Set 6 | samarai
# Processing Record 24 of Set 6 | fort nelson
# Processing Record 25 of Set 6 | bijar
# Processing Record 26 of Set 6 | xiazhen
# Processing Record 27 of Set 6 | coihaique
# Processing Record 28 of Set 6 | mar del plata
# Processing Record 29 of Set 6 | vestmannaeyjar
# Processing Record 30 of Set 6 | gusau
# Processing Record 31 of Set 6 | shache
# Processing Record 32 of Set 6 | bowen
# Processing Record 33 of Set 6 | torbay
# Processing Record 34 of Set 6 | klaksvik
# Processing Record 35 of Set 6 | hasaki
# Processing Record 36 of Set 6 | nikolskoye
# Processing Record 37 of Set 6 | saint-denis
# Processing Record 38 of Set 6 | chifeng
# Processing Record 39 of Set 6 | kavieng
# Processing Record 40 of Set 6 | chama
# Processing Record 41 of Set 6 | kattivakkam
# Processing Record 42 of Set 6 | qaqortoq
# Processing Record 43 of Set 6 | meulaboh
# Processing Record 44 of Set 6 | senno
# Processing Record 45 of Set 6 | valparaiso
# Processing Record 46 of Set 6 | flin flon
# Processing Record 47 of Set 6 | kruisfontein
# Processing Record 48 of Set 6 | gijon
# Processing Record 49 of Set 6 | ludvika
# Processing Record 50 of Set 6 | shahr-e babak
# Processing Record 1 of Set 7 | ushtobe
# Processing Record 2 of Set 7 | bilibino
# Processing Record 3 of Set 7 | dudinka
# Processing Record 4 of Set 7 | zyryanka
# Processing Record 5 of Set 7 | miri
# Processing Record 6 of Set 7 | krasnoye
# Processing Record 7 of Set 7 | pevek
# Processing Record 8 of Set 7 | koceljeva
# Processing Record 9 of Set 7 | dunhua
# Processing Record 10 of Set 7 | jiaohe
# Processing Record 11 of Set 7 | port lincoln
# Processing Record 12 of Set 7 | kichmengskiy gorodok
# Processing Record 13 of Set 7 | birao
# Processing Record 14 of Set 7 | krasne
# Processing Record 15 of Set 7 | kyzyl-suu
# Processing Record 16 of Set 7 | fukue
# Processing Record 17 of Set 7 | khandyga
# Processing Record 18 of Set 7 | salalah
# Processing Record 19 of Set 7 | dzhubga
# Processing Record 20 of Set 7 | donskoye
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | provost
# Processing Record 23 of Set 7 | sungaipenuh
# Processing Record 24 of Set 7 | sangamner
# Processing Record 25 of Set 7 | arlit
# Processing Record 26 of Set 7 | opuwo
# Processing Record 27 of Set 7 | solotcha
# Processing Record 28 of Set 7 | ullapool
# Processing Record 29 of Set 7 | illoqqortoormiut
# illoqqortoormiutwas not found in openweathermap API
# Processing Record 30 of Set 7 | madiun
# Processing Record 31 of Set 7 | svetlogorsk
# Processing Record 32 of Set 7 | tonk
# Processing Record 33 of Set 7 | san jeronimo
# Processing Record 34 of Set 7 | makuyuni
# Processing Record 35 of Set 7 | qasigiannguit
# Processing Record 36 of Set 7 | pio ix
# Processing Record 37 of Set 7 | tarakan
# Processing Record 38 of Set 7 | bathsheba
# Processing Record 39 of Set 7 | naze
# Processing Record 40 of Set 7 | lyuban
# Processing Record 41 of Set 7 | paamiut
# Processing Record 42 of Set 7 | glubokoe
# glubokoewas not found in openweathermap API
# Processing Record 43 of Set 7 | beloha
# Processing Record 44 of Set 7 | manitowoc
# Processing Record 45 of Set 7 | daru
# Processing Record 46 of Set 7 | vao
# Processing Record 47 of Set 7 | sinnamary
# Processing Record 48 of Set 7 | namatanai
# Processing Record 49 of Set 7 | amarante do maranhao
# Processing Record 50 of Set 7 | olinda
# Processing Record 1 of Set 8 | emmett
# Processing Record 2 of Set 8 | fare
# Processing Record 3 of Set 8 | matara
# Processing Record 4 of Set 8 | lorengau
# Processing Record 5 of Set 8 | ostrovnoy
# Processing Record 6 of Set 8 | berlevag
# Processing Record 7 of Set 8 | kitimat
# Processing Record 8 of Set 8 | grimshaw
# Processing Record 9 of Set 8 | sedelnikovo
# sedelnikovowas not found in openweathermap API
# Processing Record 10 of Set 8 | awjilah
# Processing Record 11 of Set 8 | dharangaon
# Processing Record 12 of Set 8 | stephenville
# Processing Record 13 of Set 8 | minab
# Processing Record 14 of Set 8 | the pas
# Processing Record 15 of Set 8 | sterling
# Processing Record 16 of Set 8 | wajir
# Processing Record 17 of Set 8 | burns lake
# Processing Record 18 of Set 8 | kenai
# Processing Record 19 of Set 8 | achisay
# achisaywas not found in openweathermap API
# Processing Record 20 of Set 8 | eyl
# Processing Record 21 of Set 8 | le mars
# Processing Record 22 of Set 8 | mount gambier
# Processing Record 23 of Set 8 | krasnoselkup
# krasnoselkupwas not found in openweathermap API
# Processing Record 24 of Set 8 | buala
# Processing Record 25 of Set 8 | novosheshminsk
# Processing Record 26 of Set 8 | vinstra
# Processing Record 27 of Set 8 | smithers
# Processing Record 28 of Set 8 | mezen
# Processing Record 29 of Set 8 | vila velha
# Processing Record 30 of Set 8 | betsiamites
# Processing Record 31 of Set 8 | buin
# Processing Record 32 of Set 8 | hirara
# Processing Record 33 of Set 8 | saint-joseph
# Processing Record 34 of Set 8 | ogulin
# Processing Record 35 of Set 8 | tukrah
# tukrahwas not found in openweathermap API
# Processing Record 36 of Set 8 | bow island
# Processing Record 37 of Set 8 | bilma
# Processing Record 38 of Set 8 | louisbourg
# louisbourgwas not found in openweathermap API
# Processing Record 39 of Set 8 | snezhnogorsk
# Processing Record 40 of Set 8 | vakhrushev
# Processing Record 41 of Set 8 | vila franca do campo
# Processing Record 42 of Set 8 | keffi
# Processing Record 43 of Set 8 | porbandar
# Processing Record 44 of Set 8 | alice springs
# Processing Record 45 of Set 8 | cayenne
# Processing Record 46 of Set 8 | edd
# Processing Record 47 of Set 8 | ciras
# ciraswas not found in openweathermap API
# Processing Record 48 of Set 8 | muhos
# Processing Record 49 of Set 8 | umm bab
# Processing Record 50 of Set 8 | progreso
# Processing Record 1 of Set 9 | porto walter
# Processing Record 2 of Set 9 | dauriya
# Processing Record 3 of Set 9 | boa vista
# Processing Record 4 of Set 9 | miles city
# Processing Record 5 of Set 9 | richards bay
# Processing Record 6 of Set 9 | wampusirpi
# wampusirpiwas not found in openweathermap API
# Processing Record 7 of Set 9 | palabuhanratu
# palabuhanratuwas not found in openweathermap API
# Processing Record 8 of Set 9 | provideniya
# Processing Record 9 of Set 9 | mulki
# Processing Record 10 of Set 9 | dovhe
# Processing Record 11 of Set 9 | rudnyy
# Processing Record 12 of Set 9 | surt
# Processing Record 13 of Set 9 | dzhebariki-khaya
# Processing Record 14 of Set 9 | muravlenko
# Processing Record 15 of Set 9 | lauf
# Processing Record 16 of Set 9 | lingao
# Processing Record 17 of Set 9 | teguldet
# Processing Record 18 of Set 9 | pedernales
# Processing Record 19 of Set 9 | tiarei
# Processing Record 20 of Set 9 | general roca
# Processing Record 21 of Set 9 | vostok
# Processing Record 22 of Set 9 | lagoa
# Processing Record 23 of Set 9 | simao
# Processing Record 24 of Set 9 | poum
# Processing Record 25 of Set 9 | iberia
# Processing Record 26 of Set 9 | luanda
# Processing Record 27 of Set 9 | karratha
# Processing Record 28 of Set 9 | oyek
# Processing Record 29 of Set 9 | karpathos
# Processing Record 30 of Set 9 | besancon
# Processing Record 31 of Set 9 | porto torres
# Processing Record 32 of Set 9 | kuznechikha
# Processing Record 33 of Set 9 | rincon de la victoria
# Processing Record 34 of Set 9 | taburi
# taburiwas not found in openweathermap API
# Processing Record 35 of Set 9 | saleaula
# saleaulawas not found in openweathermap API
# Processing Record 36 of Set 9 | rolim de moura
# rolim de mourawas not found in openweathermap API
# Processing Record 37 of Set 9 | ugoofaaru
# Processing Record 38 of Set 9 | bousso
# boussowas not found in openweathermap API
# Processing Record 39 of Set 9 | toccoa
# Processing Record 40 of Set 9 | beringovskiy
# Processing Record 41 of Set 9 | nambour
# Processing Record 42 of Set 9 | semnan
# Processing Record 43 of Set 9 | cabra
# Processing Record 44 of Set 9 | coahuayana
# Processing Record 45 of Set 9 | barkhan
# Processing Record 46 of Set 9 | dunmore east
# Processing Record 47 of Set 9 | andenes
# andeneswas not found in openweathermap API
# Processing Record 48 of Set 9 | sisimiut
# Processing Record 49 of Set 9 | selje
# Processing Record 50 of Set 9 | jalu
# Processing Record 1 of Set 10 | cam ranh
# Processing Record 2 of Set 10 | lasa
# Processing Record 3 of Set 10 | sao joao da barra
# Processing Record 4 of Set 10 | winnemucca
# Processing Record 5 of Set 10 | oriximina
# Processing Record 6 of Set 10 | kamenka
# Processing Record 7 of Set 10 | clyde river
# Processing Record 8 of Set 10 | tuggurt
# tuggurtwas not found in openweathermap API
# Processing Record 9 of Set 10 | sinkat
# sinkatwas not found in openweathermap API
# Processing Record 10 of Set 10 | half moon bay
# Processing Record 11 of Set 10 | utete
# Processing Record 12 of Set 10 | bedele
# Processing Record 13 of Set 10 | mae ramat
# Processing Record 14 of Set 10 | oranienburg
# Processing Record 15 of Set 10 | mnogovershinnyy
# Processing Record 16 of Set 10 | japura
# Processing Record 17 of Set 10 | khorixas
# Processing Record 18 of Set 10 | saint anthony
# Processing Record 19 of Set 10 | imbituba
# Processing Record 20 of Set 10 | olafsvik
# olafsvikwas not found in openweathermap API
# Processing Record 21 of Set 10 | ankpa
# Processing Record 22 of Set 10 | alofi
# Processing Record 23 of Set 10 | moussoro
# Processing Record 24 of Set 10 | torbat-e jam
# Processing Record 25 of Set 10 | chon daen
# Processing Record 26 of Set 10 | dawlatabad
# Processing Record 27 of Set 10 | kavaratti
# Processing Record 28 of Set 10 | dalbandin
# Processing Record 29 of Set 10 | gizo
# Processing Record 30 of Set 10 | bima
# Processing Record 31 of Set 10 | maceio
# Processing Record 32 of Set 10 | tazmalt
# Processing Record 33 of Set 10 | saint-prosper
# Processing Record 34 of Set 10 | mardin
# Processing Record 35 of Set 10 | chernyshevskiy
# Processing Record 36 of Set 10 | iskateley
# Processing Record 37 of Set 10 | iranshahr
# Processing Record 38 of Set 10 | bharwari
# Processing Record 39 of Set 10 | forssa
# Processing Record 40 of Set 10 | saldanha
# Processing Record 41 of Set 10 | neosho
# Processing Record 42 of Set 10 | faanui
# Processing Record 43 of Set 10 | nehe
# Processing Record 44 of Set 10 | atbasar
# Processing Record 45 of Set 10 | suhbaatar
# Processing Record 46 of Set 10 | najran
# Processing Record 47 of Set 10 | luderitz
# Processing Record 48 of Set 10 | poya
# Processing Record 49 of Set 10 | catio
# Processing Record 50 of Set 10 | basco
# Processing Record 1 of Set 11 | verkhnevilyuysk
# Processing Record 2 of Set 11 | tacna
# Processing Record 3 of Set 11 | kloulklubed
# Processing Record 4 of Set 11 | bambous virieux
# Processing Record 5 of Set 11 | rawson
# Processing Record 6 of Set 11 | mayo
# Processing Record 7 of Set 11 | hambantota
# Processing Record 8 of Set 11 | karasjok
# Processing Record 9 of Set 11 | do gonbadan
# Processing Record 10 of Set 11 | mecca
# Processing Record 11 of Set 11 | gushikawa
# Processing Record 12 of Set 11 | ilhabela
# Processing Record 13 of Set 11 | buique
# Processing Record 14 of Set 11 | san quintin
# Processing Record 15 of Set 11 | broome
# Processing Record 16 of Set 11 | goderich
# Processing Record 17 of Set 11 | jaguey grande
# Processing Record 18 of Set 11 | emba
# Processing Record 19 of Set 11 | perth
# Processing Record 20 of Set 11 | bafoulabe
# Processing Record 21 of Set 11 | huarmey
# Processing Record 22 of Set 11 | koppies
# Processing Record 23 of Set 11 | san cristobal
# Processing Record 24 of Set 11 | iwaki
# Processing Record 25 of Set 11 | paciran
# Processing Record 26 of Set 11 | sibu
# Processing Record 27 of Set 11 | tura
# Processing Record 28 of Set 11 | dera bugti
# Processing Record 29 of Set 11 | kenora
# Processing Record 30 of Set 11 | rapar
# Processing Record 31 of Set 11 | masumbwe
# Processing Record 32 of Set 11 | nizhneyansk
# nizhneyanskwas not found in openweathermap API
# Processing Record 33 of Set 11 | porto novo
# Processing Record 34 of Set 11 | mount isa
# Processing Record 35 of Set 11 | diamantina
# Processing Record 36 of Set 11 | la union
# Processing Record 37 of Set 11 | caravelas
# Processing Record 38 of Set 11 | mirador
# Processing Record 39 of Set 11 | uk
# ukwas not found in openweathermap API
# Processing Record 40 of Set 11 | biograd na moru
# Processing Record 41 of Set 11 | macae
# Processing Record 42 of Set 11 | panguna
# Processing Record 43 of Set 11 | foso
# Processing Record 44 of Set 11 | margate
# Processing Record 45 of Set 11 | qabis
# qabiswas not found in openweathermap API
# Processing Record 46 of Set 11 | ponta delgada
# Processing Record 47 of Set 11 | mahibadhoo
# Processing Record 48 of Set 11 | maputo
# Processing Record 49 of Set 11 | acari
# Processing Record 50 of Set 11 | tshikapa
# Processing Record 1 of Set 12 | port-gentil
# Processing Record 2 of Set 12 | poway
# Processing Record 3 of Set 12 | jiddah
# jiddahwas not found in openweathermap API
# Processing Record 4 of Set 12 | taxisco
# Processing Record 5 of Set 12 | santa maria
# Processing Record 6 of Set 12 | senanga
# Processing Record 7 of Set 12 | bani
# Processing Record 8 of Set 12 | nuqui
# Processing Record 9 of Set 12 | itarema
# Processing Record 10 of Set 12 | sao miguel do araguaia
# Processing Record 11 of Set 12 | gamba
# Processing Record 12 of Set 12 | bereda
# Processing Record 13 of Set 12 | ghanzi
# Processing Record 14 of Set 12 | pousat
# pousatwas not found in openweathermap API
# Processing Record 15 of Set 12 | swellendam
# Processing Record 16 of Set 12 | emborion
# Processing Record 17 of Set 12 | smiths falls
# Processing Record 18 of Set 12 | chesham
# Processing Record 19 of Set 12 | beroroha
# Processing Record 20 of Set 12 | mut
# Processing Record 21 of Set 12 | santiago del estero
# Processing Record 22 of Set 12 | florianopolis
# Processing Record 23 of Set 12 | rock hill
# Processing Record 24 of Set 12 | buarcos
# Processing Record 25 of Set 12 | patrocinio
# Processing Record 26 of Set 12 | great falls
# Processing Record 27 of Set 12 | praia da vitoria
# Processing Record 28 of Set 12 | coffs harbour
# Processing Record 29 of Set 12 | aasiaat
# Processing Record 30 of Set 12 | labutta
# labuttawas not found in openweathermap API
# Processing Record 31 of Set 12 | ayan
# Processing Record 32 of Set 12 | gamboula
# Processing Record 33 of Set 12 | abalak
# Processing Record 34 of Set 12 | yulara
# Processing Record 35 of Set 12 | buchanan
# Processing Record 36 of Set 12 | otradnoye
# Processing Record 37 of Set 12 | maloshuyka
# maloshuykawas not found in openweathermap API
# Processing Record 38 of Set 12 | tahta
# tahtawas not found in openweathermap API
# Processing Record 39 of Set 12 | auki
# Processing Record 40 of Set 12 | dingle
# Processing Record 41 of Set 12 | bihoro
# Processing Record 42 of Set 12 | satitoa
# satitoawas not found in openweathermap API
# Processing Record 43 of Set 12 | pandan
# Processing Record 44 of Set 12 | ilulissat
# Processing Record 45 of Set 12 | inongo
# Processing Record 46 of Set 12 | brodick
# Processing Record 47 of Set 12 | odweyne
# odweynewas not found in openweathermap API
# Processing Record 48 of Set 12 | ishigaki
# Processing Record 49 of Set 12 | pathein
# Processing Record 50 of Set 12 | coruripe
# Processing Record 1 of Set 13 | ucluelet
# Processing Record 2 of Set 13 | nanma
# Processing Record 3 of Set 13 | tutoia
# Processing Record 4 of Set 13 | riyadh
# Processing Record 5 of Set 13 | leh
# Processing Record 6 of Set 13 | samusu
# samusuwas not found in openweathermap API
# Processing Record 7 of Set 13 | peniche
# Processing Record 8 of Set 13 | mwene-ditu

# %%
url =  'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid='+ weather_api_key
query_url = url + "&q=" + 'Bredasdorp'
city_weather= requests.get(query_url).json()
print(city_weather)
# Out:
# {'coord': {'lon': 20.04, 'lat': -34.53}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.17, 'pressure': 1012, 'humidity': 40, 'temp_min': 66.99, 'temp_max': 71.6}, 'wind': {'speed': 16.11, 'deg': 310}, 'clouds': {'all': 0}, 'dt': 1570554663, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1570507645, 'sunset': 1570553240}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv('HWOutput_data/cities.csv', index=False, header=True)
cities_df.count()
# Out:
# City          549
# Cloudiness    549
# Country       549
# Date          549
# Humidity      549
# Lat           549
# Lng           549
# Max Temp      549
# Wind Speed    549
# dtype: int64

# %%
cities_df=pd.DataFrame({"City":city_record,"Cloudiness":city_cloud,"Country":city_country,
                       "Date":city_date,"Humidity":city_humidity,"Lat":city_lat,
                       "Lng":city_lng,"Max Temp":city_maxtemp,"Wind Speed":city_wind})

cities_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Bredasdorp           0      ZA  1570554663        40 -34.53   20.04
# 1        Qaanaaq          86      GL  1570554663        67  77.48  -69.36
# 2     Butaritari         100      KI  1570554663        66   3.07  172.79
# 3  Prince Rupert           1      CA  1570554630        69  54.32 -130.32
# 4        Bubaque          98      GW  1570554663        76  11.28  -15.83
#
#    Max Temp  Wind Speed
# 0     71.60       16.11
# 1     20.03       10.27
# 2     85.37       12.02
# 3     39.20        8.05
# 4     81.59       13.09

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.grid('whitegrid')
plt.scatter(cities_df['Lat'],cities_df['Max Temp'],edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.grid('whitegrid')
plt.scatter(cities_df['Lat'],cities_df['Humidity'],edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.grid('whitegrid')
plt.scatter(cities_df['Lat'],cities_df['Cloudiness'],edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Cloudiness')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.grid('whitegrid')
plt.scatter(cities_df['Lat'],cities_df['Wind Speed'],edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = cities_df.loc[cities_df['Lat']>0,:]
north_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1        Qaanaaq          86      GL  1570554663        67  77.48  -69.36
# 2     Butaritari         100      KI  1570554663        66   3.07  172.79
# 3  Prince Rupert           1      CA  1570554630        69  54.32 -130.32
# 4        Bubaque          98      GW  1570554663        76  11.28  -15.83
# 5       San Jose          40      HN  1570554610        62  14.25  -87.96
#
#    Max Temp  Wind Speed
# 1     20.03       10.27
# 2     85.37       12.02
# 3     39.20        8.05
# 4     81.59       13.09
# 5     84.20        6.93

# %%
south_df = cities_df.loc[cities_df['Lat']<0,:]
south_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Bredasdorp           0      ZA  1570554663        40 -34.53   20.04
# 7      Ushuaia          75      AR  1570554557        91 -54.81  -68.31
# 8      Mataura         100      NZ  1570554664        97 -46.19  168.86
# 13      Hobart          90      AU  1570554665        65 -42.88  147.33
# 14     Te Anau         100      NZ  1570554665        97 -45.41  167.72
#
#     Max Temp  Wind Speed
# 0      71.60       16.11
# 7      41.00       23.04
# 8      50.00        1.42
# 13     46.40        9.17
# 14     46.13        2.26

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=north_df['Lat']
y_values=north_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8449198916947304

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=south_df['Lat']
y_values=south_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq1= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq1,(-55,90),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.6741984903611324

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=north_df['Lat']
y_values=north_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq2= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq2,(45,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.1473482020777105

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=south_df['Lat']
y_values=south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq3= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq3,(-40,200),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.08040893563864156

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=north_df['Lat']
y_values=north_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq4= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq4,(22,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.14544033723292457

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=south_df['Lat']
y_values=south_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq5= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq5,(-55,80),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.017398047292650973

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=north_df['Lat']
y_values=north_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq6= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq6,(5,27),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.15275395393028562

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=south_df['Lat']
y_values=south_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq7= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq7,(-25,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.18555592691187425
